# %% [markdown]
# # Análise de Dados
#
# Este notebook contém a análise de dados do projeto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregamento de Dados
#
# Carregue seus dados aqui.

# %%
# df = pd.read_csv('dados.csv')
# df.head()

# %% [markdown]
# ## Análise Exploratória
#
# Realize a análise exploratória dos dados.

# %%
# df.describe()

# %% [markdown]
# ## Visualização
#
# Crie visualizações dos dados.

# %%
# plt.figure(figsize=(10, 6))
# plt.show()
